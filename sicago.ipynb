# %% [markdown]
# ## 1. 웹 데이터 가져오는 Beautiful Soup 익히기

# %%
import pandas as pd
import numpy as np

# %%
# !pip3 install beautifulsoup4
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 KB 8.4 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
# BeautifulSoup import
from bs4 import BeautifulSoup

# %%
# html 파일 읽기
page = open('/Users/t2023-m0089/python/3. practice_python/python_joomooloogi/sicago_sandwichi/03. test_first.html', 'r').read()
soup = BeautifulSoup(page, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Very Simple HTML Code by PinkWink
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     Happy PinkWink.
#     <a href="http://www.pinkwink.kr" id="pw-link">
#      PinkWink
#     </a>
#    </p>
#    <p class="inner-text second-item">
#     Happy Data Science.
#     <a href="https://www.python.org" id="py-link">
#      Python
#     </a>
#    </p>
#   </div>
#   <p class="outer-text first-item" id="second">
#    <b>
#     Data Science is funny.
#    </b>
#   </p>
#   <p class="outer-text">
#    <b>
#     All I need is Love.
#    </b>
#   </p>
#  </body>
# </html>

# %% [markdown]
# - open(): 지정된 경로에 있는 파일을 열어 내용을 읽습니다.
#     - 첫 번째 인자: '파일 경로'는 로컬에 있는 HTML 파일의 경로입니다.
#     - 두 번째 인자: 'r'은 파일을 **읽기 모드(read mode)**로 연다는 의미입니다.
# - .read(): 파일의 내용을 한 번에 모두 읽어와 문자열 형태로 반환합니다.
#     - 결과적으로, page 변수에는 해당 HTML 파일의 내용이 문자열로 저장됩니다.
# - BeautifulSoup(page, 'html.parser'): BeautifulSoup 객체를 생성하여 HTML 코드를 파싱합니다.
#     - 첫 번째 인자: page는 앞서 읽어온 HTML 파일의 내용입니다.
#     - 두 번째 인자: 'html.parser'는 기본 제공되는 Python의 내장 HTML 파서를 사용하여 HTML을 분석합니다.
# - 결과적으로, soup 변수에는 파싱된 HTML 구조가 저장됩니다.
# - soup.prettify(): BeautifulSoup 객체에서 제공하는 메서드로, HTML 코드를 보기 좋게 들여쓰기(indent)하여 출력합니다.
#     - 원래는 한 줄로 되어 있거나 들여쓰기가 없는 HTML 코드도 이 메서드를 사용하면 사람이 읽기 쉽게 정리됩니다.
# - print(): prettify() 메서드로 정리된 HTML 코드를 콘솔에 출력합니다.

# %%
# soup는 문서 전체를 저장한 변수이기 때문에 그 안에서 html 태그에 접속하고 싶다면,
html = list(soup.children)[2]
html
# Out:
# <html>
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %%
# 본문으로 보는 body 태그를 보기 위해 3번 인덱스 조사
body = list(html.children)[3]
body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
# 위 과정 없이 바로 body 검색 가능
soup.body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
# 접근한 태그를 알고 있다면 find_all 명령 사용
soup.find_all('p')
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>,
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>,
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
# p 태그의 class가 outer-text인 것을 찾는 것도 가능

soup.find_all(class_='outer-text')
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find_all(id = 'first')
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>]

# %%
# get_text() 명령으로 태그 안에 있는 텍스트만 추출
for each_tag in soup.find_all('p'):
    print(each_tag.get_text())
# Out:
#                 Happy PinkWink.
#                 PinkWink
#
#
#                 Happy Data Science.
#                 Python
#
#
#
#                 Data Science is funny.
#
#
#
#
#                 All I need is Love.

# %%
# 클릭 가능한 링크 a 태그
links = soup.find_all('a')
links
# Out:
# [<a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>,
#  <a href="https://www.python.org" id="py-link">Python</a>]

# %%
# href 속성을 찾으면 링크 주소 추출 가능

for each in links:
    href = each['href']
    text = each.string
    print(text, '->', href)
# Out:
# PinkWink -> http://www.pinkwink.kr
# Python -> https://www.python.org

# %%
import requests
from bs4 import BeautifulSoup

# requests로 페이지 가져오기 (SSL 처리 자동)
url = 'https://finance.naver.com/marketindex/'
response = requests.get(url)

# BeautifulSoup으로 HTML 파싱
soup = BeautifulSoup(response.text, 'html.parser')

# 보기 좋게 출력
print(soup.prettify())
# Out:
# <script language="javascript" src="/template/head_js.naver?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20241104162211/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20241104162211/js/jindo.1.5.3.element-text-patch.js" type="text/javascript">
# </script>
# <div id="container" style="padding-bottom:0px;">
#  <div class="market_include">
#   <div class="market_data">
#    <div class="market1">
#     <div class="title">
#      <h2 class="h_market1">
#       <span>
#        환전 고시 환율
#       </span>
#      </h2>
#     </div>
#     <!-- data -->
#     <div class="data">
#      <ul class="data_lst" id="exchangeList">
#       <li class="on">
#        <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# ...

# %%
soup.find_all('span', 'value')[0].string
# Out:
# '1,396.50'

# %% [markdown]
# - soup.find_all('span', 'value'): find_all() 메서드를 사용하여 모든 <span> 태그 중에서 class="value"인 요소들을 찾아 리스트로 반환합니다.

# %% [markdown]
# ## 2. 실전: 시카고 샌드위치 맛집 소개 사이트 접근

# %% [markdown]
# - https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-Chicago/
# - 데이터 수집 목표: 가게 이름, 가게 메인 메뉴, 각 가게 소개 페이지

# %%
import requests
from bs4 import BeautifulSoup

# User-Agent를 브라우저처럼 설정
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
}

# URL 설정
url_base = 'https://www.chicagomag.com'
url = 'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-Chicago/'

# 페이지 요청 (User-Agent 포함)
html = requests.get(url, headers=headers)

# BeautifulSoup으로 HTML 파싱
soup = BeautifulSoup(html.text, 'html.parser')

# 보기 좋게 출력
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible">
#    <link href="https://gmpg.org/xfn/11" rel="profile"/>
#    <script src="https://cmp.osano.com/16A1AnRt2Fn8i1unj/f15ebf08-7008-40fe-9af3-db96dc3e8266/osano.js">
#    </script>
#    <title>
#     The 50 Best Sandwiches in Chicago – Chicago Magazine
#    </title>
#    <style type="text/css">
#     .heateor_sss_button_instagram span.heateor_sss_svg,a.heateor_sss_instagram span.heateor_sss_svg{background:radial-gradient(circle at 30% 107%,#fdf497 0,#fdf497 5%,#fd5949 45%,#d6249f 60%,#285aeb 90%)}
# 						div.heateor_sss_horizontal_sharing a.heateor_sss_button_instagram span{background:#000!important;}div.heateor_sss_standard_follow_icons_container a.heateor_sss_button_instagram span{background:#000;}
# 										.heateor_sss_horizontal_sharing .heateor_sss_svg,.heateor_sss_standard_follow_icons_container .heateor_sss_svg{
# ...

# %%
# 가게 이름 등의 정보가 있는 태그 검색, 크롬 브라우저에서 해당 위치 우선 탐색 필요
soup.find_all('div', 'sammy')
# Out:
# [<div class="sammy" style="position: relative;">
#  <div class="sammyRank">1</div>
#  <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
#  Old Oak Tap<br/>
#  <em>Read more</em> </a></div>
#  </div>,
#  <div class="sammy" style="position: relative;">
#  <div class="sammyRank">2</div>
#  <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/"><b>Fried Bologna</b><br/>
#  Au Cheval<br/>
#  <em>Read more</em> </a></div>
#  </div>,
#  <div class="sammy" style="position: relative;">
#  <div class="sammyRank">3</div>
#  <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/"><b>Woodland Mushroom</b><br/>
#  Xoco<br/>
#  <em>Read more</em> </a></div>
#  </div>,
#  <div class="sammy" style="position: relative;">
#  <div class="sammyRank">4</div>
# ...

# %%
# len 명령어로 맛집 50개와 길이가 동일한지 확인
len(soup.find_all('div', 'sammy'))
# Out:
# 50

# %%
# 정보 확인. 
soup.find_all('div', 'sammy')[0]
# Out:
# <div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
# Old Oak Tap<br/>
# <em>Read more</em> </a></div>
# </div>

# %% [markdown]
# ## 3. 접근한 웹 페이지에서 원하는 데이터 추출하고 정리하기

# %%
tmp_one = soup.find_all('div', 'sammy')[0]
type(tmp_one)
# Out:
# bs4.element.Tag

# %%
# bs4.element.Tag인 경우 그 변수에 다시 태그로 찾는 명령 사용 가능
# 텍스트만 추출 get.text()

print('랭킹 순위:', tmp_one.find(class_= 'sammyRank').get_text())
print('메뉴 및 가게 이름:', tmp_one.find(class_= 'sammyListing').get_text())
# Out:
# 랭킹 순위: 1
# 메뉴 및 가게 이름: BLT
# Old Oak Tap
# Read more

# %%
# 연결된 주소 저장 가능
tmp_one.find('a')['href']
# Out:
# '/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
# 가게 이름과 메뉴 분리
# 정규식(Regular Express)

import re

tmp_string = tmp_one.find(class_ = 'sammyListing').get_text()

re.split(('\n|\r\n'), tmp_string)

print(re.split(('\n|\r\n'), tmp_string)[0])
print(re.split(('\n|\r\n'), tmp_string)[1])
# Out:
# BLT
# Old Oak Tap

# %% [markdown]
# - re.split(('\n|\r\n'), tmp_string):
#     - 정규식을 사용하여 문자열을 줄바꿈 문자(\n 또는 \r\n) 기준으로 분리합니다.
#     - \n은 줄바꿈(newline)을 의미하고, \r\n은 캐리지 리턴과 줄바꿈이 함께 사용되는 경우를 의미합니다. 두 가지 경우 모두 줄바꿈으로 처리됩니다.
#     - 예시로, tmp_string이 "가게 이름\n메뉴 1\n메뉴 2"라면, 이 코드는 이를 ['가게 이름', '메뉴 1', '메뉴 2']로 분리합니다.

# %%
from urllib.parse import urljoin  # urljoin을 가져옴

# 데이터 저장 리스트 초기화
rank = []
main_menu = []
cafe_name = []
url_add = []

# 'sammy' 클래스를 가진 div 요소들을 모두 찾음
list_soup = soup.find_all('div', 'sammy')

for item in list_soup:
    # 랭킹 정보 추출
    rank.append(item.find(class_='sammyRank').get_text())
    
    # 가게 이름과 메뉴 정보 추출
    tmp_string = item.find(class_='sammyListing').get_text()
    main_menu.append(re.split(('\n|\r\n'), tmp_string)[0])
    cafe_name.append(re.split(('\n|\r\n'), tmp_string)[1])
    
    # 상대 URL을 절대 URL로 변환하여 추가
    url_add.append(urljoin(url_base, item.find('a')['href']))

# 결과 확인
print(rank[:5])
print(cafe_name[:5])
print(main_menu[:5])
print(url_add[:5])
# Out:
# ['1', '2', '3', '4', '5']
# ['Old Oak Tap', 'Au Cheval', 'Xoco', 'Al’s Deli', 'Publican Quality Meats']
# ['BLT', 'Fried Bologna', 'Woodland Mushroom', 'Roast Beef', 'PB&L']
# ['https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/', 'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/', 'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/', 'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Als-Deli-Roast-Beef/', 'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Publican-Quality-Meats-PB-L/']

# %%
# 결과 확인
len(rank), len(main_menu), len(cafe_name), len(url_add)
# Out:
# (50, 50, 50, 50)

# %%
data = {
    'Rank': rank,
    'Cafe': cafe_name,
    'Menu': main_menu,
    'URL': url_add
}
sicago_df = pd.DataFrame(data)
sicago_df.head()
# Out:
#   Rank                    Cafe               Menu  \
# 0    1             Old Oak Tap                BLT
# 1    2               Au Cheval      Fried Bologna
# 2    3                    Xoco  Woodland Mushroom
# 3    4               Al’s Deli         Roast Beef
# 4    5  Publican Quality Meats               PB&L
#
#                                                  URL
# 0  https://www.chicagomag.com/Chicago-Magazine/No...
# 1  https://www.chicagomag.com/Chicago-Magazine/No...
# 2  https://www.chicagomag.com/Chicago-Magazine/No...
# 3  https://www.chicagomag.com/Chicago-Magazine/No...
# 4  https://www.chicagomag.com/Chicago-Magazine/No...

# %%
sicago_df.to_csv('/Users/t2023-m0089/python/3. practice_python/python_joomooloogi/sicago_sandwichi/sicago_df.csv', sep = ',', encoding='utf-8')

# %%
sicago_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rank    50 non-null     object
#  1   Cafe    50 non-null     object
#  2   Menu    50 non-null     object
#  3   URL     50 non-null     object
# dtypes: object(4)
# memory usage: 1.7+ KB

# %% [markdown]
# ## 4. 다수의 웹 페이지에서 자동으로 접근해 원하는 정보 가져오기

# %%
# 첫 번째 url로 원하는 정보 가져오기 테스트
sicago_df['URL'][0]
# Out:
# 'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
# User-Agent를 브라우저처럼 설정
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
}

# URL 가져오기
url = sicago_df['URL'][0]

# 페이지 요청 (User-Agent 포함)
html1 = requests.get(url, headers=headers)

# BeautifulSoup으로 HTML 파싱
soup1 = BeautifulSoup(html1.text, 'html.parser')

print(soup1.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible">
#    <link href="https://gmpg.org/xfn/11" rel="profile"/>
#    <script src="https://cmp.osano.com/16A1AnRt2Fn8i1unj/f15ebf08-7008-40fe-9af3-db96dc3e8266/osano.js">
#    </script>
#    <title>
#     1. Old Oak Tap BLT – Chicago Magazine
#    </title>
#    <style type="text/css">
#     .heateor_sss_button_instagram span.heateor_sss_svg,a.heateor_sss_instagram span.heateor_sss_svg{background:radial-gradient(circle at 30% 107%,#fdf497 0,#fdf497 5%,#fd5949 45%,#d6249f 60%,#285aeb 90%)}
# 						div.heateor_sss_horizontal_sharing a.heateor_sss_button_instagram span{background:#000!important;}div.heateor_sss_standard_follow_icons_container a.heateor_sss_button_instagram span{background:#000;}
# 										.heateor_sss_horizontal_sharing .heateor_sss_svg,.heateor_sss_standard_follow_icons_container .heateor_sss_svg{
# 							background-color: #000!important;
# ...

# %%
print(soup1.find('p', 'addy'))
# Out:
# <p class="addy">
# <em>$10. 2109 W. Chicago Ave., 773-772-0406, <a href="http://www.theoldoaktap.com/">theoldoaktap.com</a></em></p>

# %%
# 원하는 정보: 주소, 가격, 전화번호를 텍스트로 추출
price_tmp = soup1.find('p', 'addy').get_text()
price_tmp
# Out:
# '\n$10. 2109 W. Chicago Ave., 773-772-0406, theoldoaktap.com'

# %%
# split 사용하여 구분
print('가격:', price_tmp.split()[0][:-1])
print('주소:', ' '.join(price_tmp.split()[1:-2]))
print('웹 주소:', price_tmp.split()[-1][:-1])
print('전화번호:', price_tmp.split()[-2][:-1])
# Out:
# 가격: $10
# 주소: 2109 W. Chicago Ave.,
# 웹 주소: theoldoaktap.co
# 전화번호: 773-772-0406

# %%
sicago_df.head()
# Out:
#   Rank                    Cafe               Menu  \
# 0    1             Old Oak Tap                BLT
# 1    2               Au Cheval      Fried Bologna
# 2    3                    Xoco  Woodland Mushroom
# 3    4               Al’s Deli         Roast Beef
# 4    5  Publican Quality Meats               PB&L
#
#                                                  URL
# 0  https://www.chicagomag.com/Chicago-Magazine/No...
# 1  https://www.chicagomag.com/Chicago-Magazine/No...
# 2  https://www.chicagomag.com/Chicago-Magazine/No...
# 3  https://www.chicagomag.com/Chicago-Magazine/No...
# 4  https://www.chicagomag.com/Chicago-Magazine/No...

# %%
# 페이지 3개 테스트

price = []
address = []
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
}
telephone = []
webpage = []

for n in sicago_df.index[:3]:
    html = requests.get(sicago_df['URL'][n], headers=headers)
    soup_tmp = BeautifulSoup(html.text, 'html.parser')
    
    gettings = soup_tmp.find('p', 'addy').get_text()
    
    price.append(gettings.split()[0][:-1])
    address.append(' '.join(gettings.split()[1:-2]))
    telephone.append(gettings.split()[-2][:-1])
    webpage.append(gettings.split()[-1][:-1])
    
    
print(price)
print(address)
print(telephone)
print(webpage)
# Out:
# ['$10', '$9', '$9.50']
# ['2109 W. Chicago Ave.,', '800 W. Randolph St.,', '445 N. Clark St.,']
# ['773-772-0406', '312-929-4580', '312-334-3688']
# ['theoldoaktap.co', 'aucheval.tumblr.co', 'rickbayless.co']

# %%
# 페이지 50개 진행
# 상태바 tqdm import

from tqdm import tqdm

price = []
address = []
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
}
telephone = []
webpage = []

for n in tqdm(sicago_df.index):
    html = requests.get(sicago_df['URL'][n], headers=headers)
    soup_tmp = BeautifulSoup(html.text, 'html.parser')
    
    gettings = soup_tmp.find('p', 'addy').get_text()
    
    price.append(gettings.split()[0][:-1])
    address.append(' '.join(gettings.split()[1:-2]))
    telephone.append(gettings.split()[-2][:-1])
    webpage.append(gettings.split()[-1][:-1])
    
    
print(price)
print(address)
print(telephone)
print(webpage)
# Out:
# Exception ignored in: <function tqdm.__del__ at 0x7f7d7948a670>
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm_notebook' object has no attribute 'disp'
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 50/50 [01:22<00:00,  1.65s/it]
# ['$10', '$9', '$9.50', '$9.40', '$10', '$7.25', '$16', '$10', '$9', '$17', '$11', '$5.49', '$14', '$10', '$13', '$4.50', '$11.95', '$11.50', '$6.25', '$15', '$5', '$6', '$8', '$5.99', '$7.52', '$11.95', '$7.50', '$12.95', '$7', '$21', '$9.79', '$9.75', '$13', '$7.95', '$9', '$9', '$8', '$8', '$7', '$6', '$7.25', '$11', '$6', '$9', '$5.49', '$8', '$6.50', '$7.50', '$8.75', '$6.85']
# ...

# %%
len(price), len(address), len(sicago_df)
# Out:
# (50, 50, 50)

# %%
sicago_df['Price'] = price
sicago_df['Address'] = address
sicago_df['Telephone'] = telephone
sicago_df['Webpage'] = webpage

sicago_df.head()
# Out:
#   Rank                    Cafe               Menu  \
# 0    1             Old Oak Tap                BLT
# 1    2               Au Cheval      Fried Bologna
# 2    3                    Xoco  Woodland Mushroom
# 3    4               Al’s Deli         Roast Beef
# 4    5  Publican Quality Meats               PB&L
#
#                                                  URL  Price  \
# 0  https://www.chicagomag.com/Chicago-Magazine/No...    $10
# 1  https://www.chicagomag.com/Chicago-Magazine/No...     $9
# 2  https://www.chicagomag.com/Chicago-Magazine/No...  $9.50
# 3  https://www.chicagomag.com/Chicago-Magazine/No...  $9.40
# 4  https://www.chicagomag.com/Chicago-Magazine/No...    $10
#
#                     Address     Telephone                  Webpage
# 0     2109 W. Chicago Ave.,  773-772-0406          theoldoaktap.co
# 1      800 W. Randolph St.,  312-929-4580       aucheval.tumblr.co
# 2         445 N. Clark St.,  312-334-3688           rickbayless.co
# ...

# %%
# Rank 인덱스화
sicago_df.set_index('Rank', inplace=True)
sicago_df.head()
# Out:
#                         Cafe               Menu  \
# Rank
# 1                Old Oak Tap                BLT
# 2                  Au Cheval      Fried Bologna
# 3                       Xoco  Woodland Mushroom
# 4                  Al’s Deli         Roast Beef
# 5     Publican Quality Meats               PB&L
#
#                                                     URL  Price  \
# Rank
# 1     https://www.chicagomag.com/Chicago-Magazine/No...    $10
# 2     https://www.chicagomag.com/Chicago-Magazine/No...     $9
# 3     https://www.chicagomag.com/Chicago-Magazine/No...  $9.50
# 4     https://www.chicagomag.com/Chicago-Magazine/No...  $9.40
# 5     https://www.chicagomag.com/Chicago-Magazine/No...    $10
#
#                        Address     Telephone                  Webpage
# Rank
# 1        2109 W. Chicago Ave.,  773-772-0406          theoldoaktap.co
# 2         800 W. Randolph St.,  312-929-4580       aucheval.tumblr.co
# ...

# %%
# 컬럼 순서 변경
df = sicago_df.loc[:, ['Cafe', 'Menu', 'Price', 'Address', 'Telephone', 'Webpage', 'URL']]
df.head()
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address     Telephone                  Webpage  \
# Rank
# 1        2109 W. Chicago Ave.,  773-772-0406          theoldoaktap.co
# 2         800 W. Randolph St.,  312-929-4580       aucheval.tumblr.co
# 3            445 N. Clark St.,  312-334-3688           rickbayless.co
# 4     914 Noyes St., Evanston,  847-475-9400               alsdeli.ne
# 5          825 W. Fulton Mkt.,  312-445-8977  publicanqualitymeats.co
#
#                                                     URL
# Rank
# 1     https://www.chicagomag.com/Chicago-Magazine/No...
# 2     https://www.chicagomag.com/Chicago-Magazine/No...
# ...

# %%
df.to_csv('/Users/t2023-m0089/python/3. practice_python/python_joomooloogi/sicago_sandwichi/sicago2.csv', sep = ',', encoding='utf-8')

# %%
df = pd.read_csv('/Users/t2023-m0089/python/3. practice_python/python_joomooloogi/sicago_sandwichi/sicago2.csv', index_col=0)
df.head()
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address     Telephone                  Webpage  \
# Rank
# 1        2109 W. Chicago Ave.,  773-772-0406          theoldoaktap.co
# 2         800 W. Randolph St.,  312-929-4580       aucheval.tumblr.co
# 3            445 N. Clark St.,  312-334-3688           rickbayless.co
# 4     914 Noyes St., Evanston,  847-475-9400               alsdeli.ne
# 5          825 W. Fulton Mkt.,  312-445-8977  publicanqualitymeats.co
#
#                                                     URL
# Rank
# 1     https://www.chicagomag.com/Chicago-Magazine/No...
# 2     https://www.chicagomag.com/Chicago-Magazine/No...
# ...

# %% [markdown]
# ## 5. 맛집 위치를 지도에 표기하기

# %%
import folium
import googlemaps

# %%
# googlemaps를 이용해 API 키 저장
gmaps_key = 'AIzaSyD3F7aaRwZAW8xtgiQPd_vZlwL10S5En6Q'
gmaps = googlemaps.Client(key = gmaps_key)

# %%
df
# Out:
#                                  Cafe  \
# Rank
# 1                         Old Oak Tap
# 2                           Au Cheval
# 3                                Xoco
# 4                           Al’s Deli
# 5              Publican Quality Meats
# 6     Hendrickx Belgian Bread Crafter
# 7                              Acadia
# 8                   Birchwood Kitchen
# 9                      Cemitas Puebla
# 10                               Nana
# 11                          Lula Cafe
# 12                         Ricobene’s
# 13                       Frog n Snail
# 14                   Crosby’s Kitchen
# 15                    Longman & Eagle
# 16                               Bari
# 17                            Manny’s
# 18                             Eggy’s
# 19                      Old Jerusalem
# 20               Mindy’s HotChocolate
# 21                Olga’s Delicatessen
# 22       Dawali Mediterranean Kitchen
# 23                          Big Jones
# ...

# %%
# 50개 맛집의 위도, 경도 정보 불러오기

from tqdm import tqdm

lat = []
lng = []

for n in tqdm(df.index):
    if df['Address'][n] != 'Mutiple':
        target_name = df['Address'][n] + ', ' + 'Chicago'
        gmaps_output = gmaps.geocode(target_name)
        location_output = gmaps_output[0].get('geometry')
        lat.append(location_output['location']['lat'])
        lng.append(location_output['location']['lng'])
    else: 
        lat.append(np.nan)
        lng.append(np.nan)
# Out:
# 100%|██████████| 50/50 [00:08<00:00,  6.01it/s]

# %%
# 위도 경도 데이터프레임 추가
df['lat'] = lat
df['lng'] = lng
df.head()
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address     Telephone                  Webpage  \
# Rank
# 1        2109 W. Chicago Ave.,  773-772-0406          theoldoaktap.co
# 2         800 W. Randolph St.,  312-929-4580       aucheval.tumblr.co
# 3            445 N. Clark St.,  312-334-3688           rickbayless.co
# 4     914 Noyes St., Evanston,  847-475-9400               alsdeli.ne
# 5          825 W. Fulton Mkt.,  312-445-8977  publicanqualitymeats.co
#
#                                                     URL        lat        lng
# Rank
# 1     https://www.chicagomag.com/Chicago-Magazine/No...  41.895589 -87.679962
# ...

# %%
# 50개 맛집 위도, 경도의 평균값을 중앙에 위치

mapping = folium.Map(location = [df['lat'].mean(), df['lng'].mean()], zoom_start=11)
folium.Marker([df['lat'].mean(), df['lng'].mean()], popup = 'center').add_to(mapping)

mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# 50맛집 위도, 경도 지도에 표기

mapping = folium.Map(location = [df['lat'].mean(), df['lng'].mean()], zoom_start=11)

for n in df.index:
    if df['Address'][n] != 'Multiple':
        folium.Marker([df['lat'][n], df['lng'][n]], popup = df['Cafe'][n]).add_to(mapping)
        
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## 번외. 네이버 영화 평점 기준 영화의 평점 변화 알아보기
